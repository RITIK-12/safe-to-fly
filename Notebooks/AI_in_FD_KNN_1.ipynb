# %% [markdown]
# <a href="https://colab.research.google.com/github/RITIK-12/safe-to-fly/blob/main/Notebooks/AI_in_FD_KNN_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('/content/drive/MyDrive/AIFD_project/Work_2/notebooks/df_21_multiclass.csv')
df
# Out:
#          time       phi       psi     theta  mode  ...   m1   m2  add1  add2  fault
# 0        44.0 -0.012684  3.128628 -0.075276   0.0  ...  1.0  1.0   0.0   0.0      0
# 1        44.1 -0.012709  3.128594 -0.075270   0.0  ...  1.0  1.0   0.0   0.0      0
# 2        44.2 -0.012701  3.128564 -0.075245   0.0  ...  1.0  1.0   0.0   0.0      0
# 3        44.3 -0.012707  3.128566 -0.075279   0.0  ...  1.0  1.0   0.0   0.0      0
# 4        44.4 -0.012700  3.128508 -0.075287   0.0  ...  1.0  1.0   0.0   0.0      0
# ...       ...       ...       ...       ...   ...  ...  ...  ...   ...   ...    ...
# 29836  3024.5 -0.016261  2.236397 -0.071989   0.0  ...  1.0  1.0   0.0   0.0      0
# 29837  3024.6 -0.016258  2.236219 -0.071986   0.0  ...  1.0  1.0   0.0   0.0      0
# 29838  3024.7 -0.016252  2.236067 -0.071989   0.0  ...  1.0  1.0   0.0   0.0      0
# 29839  3024.8 -0.016300  2.235881 -0.071985   0.0  ...  1.0  1.0   0.0   0.0      0
# ...

# %%
import seaborn as sns
g = sns.countplot(df['fault'])
g.set_xticklabels(['nominal','d1','d2=0.9','d2=0.8','d2=0.7','d2=0.6','d2=0.5','d2=0.4','d2=0.3'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.20)

# %%
X_train.shape
# Out:
# (23872, 49)

# %%
X_test.shape
# Out:
# (5969, 49)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_test, y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 0.97
# Accuracy of K-NN classifier on test set: 0.93

# %%
pred = knn.predict(X_test)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      2933
#            1       0.99      0.98      0.99       507
#            2       0.74      0.70      0.72       276
#            3       0.67      0.68      0.67       306
#            4       0.75      0.66      0.70       321
#            5       0.84      0.85      0.84       336
#            6       0.86      0.88      0.87       296
#            7       0.96      0.94      0.95       299
#            8       1.00      0.99      0.99       695
#
#     accuracy                           0.93      5969
#    macro avg       0.86      0.85      0.86      5969
# weighted avg       0.93      0.93      0.93      5969

# %%
cm = confusion_matrix(y_test, pred)
cm
# Out:
# array([[2909,    6,   17,    0,    0,    0,    0,    0,    1],
#        [   9,  498,    0,    0,    0,    0,    0,    0,    0],
#        [  48,    0,  192,   33,    3,    0,    0,    0,    0],
#        [  12,    0,   44,  208,   40,    2,    0,    0,    0],
#        [   1,    0,    8,   70,  213,   28,    1,    0,    0],
#        [   0,    0,    0,    1,   28,  284,   23,    0,    0],
#        [   0,    0,    0,    0,    1,   26,  261,    8,    0],
#        [   0,    0,    0,    0,    0,    0,   17,  282,    0],
#        [   3,    0,    0,    0,    0,    0,    0,    4,  688]])

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

plt.show()

# %%
.

# %% [markdown]
# ## now for pred 23

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X, y)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X, y)))
# Out:
# Accuracy of K-NN classifier on training set: 0.98

# %%
df_23 = pd.read_csv('/content/drive/MyDrive/AIFD_project/Work_2/notebooks/df_23_multiclass.csv')

# %%
df_23
# Out:
#          time       phi       psi     theta  mode  ...   m1   m2  add1  add2  fault
# 0        44.0 -0.019257  3.113642 -0.075649   0.0  ...  1.0  1.0   0.0   0.0      0
# 1        44.1 -0.019314  3.113563 -0.075712   0.0  ...  1.0  1.0   0.0   0.0      0
# 2        44.2 -0.019308  3.113501 -0.075723   0.0  ...  1.0  1.0   0.0   0.0      0
# 3        44.3 -0.019300  3.113426 -0.075736   0.0  ...  1.0  1.0   0.0   0.0      0
# 4        44.4 -0.019351  3.113332 -0.075727   0.0  ...  1.0  1.0   0.0   0.0      0
# ...       ...       ...       ...       ...   ...  ...  ...  ...   ...   ...    ...
# 32282  3269.5 -0.017212 -3.020877 -0.070188   0.0  ...  1.0  1.0   0.0   0.0      0
# 32283  3269.6 -0.015179 -3.021151 -0.069231   0.0  ...  1.0  1.0   0.0   0.0      0
# 32284  3269.7 -0.014398 -3.020987 -0.068787   0.0  ...  1.0  1.0   0.0   0.0      0
# 32285  3269.8 -0.013408 -3.020862 -0.068531   0.0  ...  1.0  1.0   0.0   0.0      0
# ...

# %%
X_23 = df_23.iloc[:,:-1]
y_23 = df_23.iloc[:,-1]

# %%
pred_23 = knn.predict(X_23)

# %%
print(classification_report(y_23, pred_23))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90     16955
#            1       0.87      0.49      0.63      2527
#            2       0.28      0.24      0.26      1431
#            3       0.26      0.21      0.23      1458
#            4       0.30      0.33      0.31      1481
#            5       0.23      0.18      0.20      1505
#            6       0.37      0.41      0.39      1549
#            7       0.50      0.47      0.48      1620
#            8       0.82      0.90      0.86      3761
#
#     accuracy                           0.72     32287
#    macro avg       0.50      0.46      0.47     32287
# weighted avg       0.71      0.72      0.71     32287

# %%
cm = confusion_matrix(y_23, pred_23)
cm
# Out:
# array([[15869,   177,   523,   229,    74,    36,     9,     4,    34],
#        [ 1272,  1237,     0,     6,     3,     2,     1,     1,     5],
#        [  652,     0,   345,   243,   140,    50,     0,     0,     1],
#        [  328,     0,   251,   300,   341,   195,    35,     8,     0],
#        [   76,     1,    99,   221,   482,   324,   256,    19,     3],
#        [   53,     1,    24,   124,   393,   268,   455,   148,    39],
#        [   25,     0,     2,    19,   187,   228,   633,   387,    68],
#        [    7,     0,     3,     1,     2,    44,   223,   758,   582],
#        [   42,     1,     5,     2,     3,    18,    89,   205,  3396]])

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

plt.show()
