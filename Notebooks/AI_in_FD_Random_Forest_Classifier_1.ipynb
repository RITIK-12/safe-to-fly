# %% [markdown]
# <a href="https://colab.research.google.com/github/RITIK-12/safe-to-fly/blob/main/Notebooks/AI_in_FD_Random_Forest_Classifier_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('/content/drive/MyDrive/AIFD_project/Work_2/notebooks/df_21_multiclass.csv')
df
# Out:
#          time       phi       psi     theta  mode  ...   m1   m2  add1  add2  fault
# 0        44.0 -0.012684  3.128628 -0.075276   0.0  ...  1.0  1.0   0.0   0.0      0
# 1        44.1 -0.012709  3.128594 -0.075270   0.0  ...  1.0  1.0   0.0   0.0      0
# 2        44.2 -0.012701  3.128564 -0.075245   0.0  ...  1.0  1.0   0.0   0.0      0
# 3        44.3 -0.012707  3.128566 -0.075279   0.0  ...  1.0  1.0   0.0   0.0      0
# 4        44.4 -0.012700  3.128508 -0.075287   0.0  ...  1.0  1.0   0.0   0.0      0
# ...       ...       ...       ...       ...   ...  ...  ...  ...   ...   ...    ...
# 29836  3024.5 -0.016261  2.236397 -0.071989   0.0  ...  1.0  1.0   0.0   0.0      0
# 29837  3024.6 -0.016258  2.236219 -0.071986   0.0  ...  1.0  1.0   0.0   0.0      0
# 29838  3024.7 -0.016252  2.236067 -0.071989   0.0  ...  1.0  1.0   0.0   0.0      0
# 29839  3024.8 -0.016300  2.235881 -0.071985   0.0  ...  1.0  1.0   0.0   0.0      0
# 29840  3024.9 -0.016312  2.235734 -0.071982   0.0  ...  1.0  1.0   0.0   0.0      0
#
# [29841 rows x 50 columns]

# %%
import seaborn as sns
g = sns.countplot(df['fault'])
g.set_xticklabels(['nominal','d1','d2=0.9','d2=0.8','d2=0.7','d2=0.6','d2=0.5','d2=0.4','d2=0.3'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.20)

# %%
X_train.shape
# Out:
# (23872, 49)

# %%
X_test.shape
# Out:
# (5969, 49)

# %%
clf = RandomForestClassifier(max_depth=3, random_state=0)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3, random_state=0)

# %%
pred = clf.predict(X_test)

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91      2921
#            1       1.00      0.71      0.83       454
#            2       0.94      0.59      0.72       323
#            3       0.81      0.15      0.26       310
#            4       0.33      0.08      0.13       291
#            5       0.57      0.89      0.69       311
#            6       0.92      0.59      0.72       321
#            7       0.65      0.75      0.70       313
#            8       0.92      0.97      0.94       725
#
#     accuracy                           0.82      5969
#    macro avg       0.78      0.64      0.66      5969
# weighted avg       0.82      0.82      0.79      5969

# %%
cm = confusion_matrix(y_test, pred)
cm
# Out:
# array([[2920,    0,    0,    0,    0,    0,    0,    0,    1],
#        [ 130,  324,    0,    0,    0,    0,    0,    0,    0],
#        [ 133,    0,  190,    0,    0,    0,    0,    0,    0],
#        [ 178,    0,   12,   47,   46,   27,    0,    0,    0],
#        [  82,    0,    0,   10,   23,  176,    0,    0,    0],
#        [  27,    0,    0,    1,    0,  276,    0,    7,    0],
#        [  24,    0,    0,    0,    0,    4,  188,  103,    2],
#        [   1,    0,    0,    0,    0,    1,   16,  235,   60],
#        [   2,    0,    0,    0,    0,    0,    0,   18,  705]])

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

plt.show()

# %% [markdown]
# ## now for pred 23

# %%
clf = RandomForestClassifier(max_depth=3, random_state=0)
clf.fit(X, y)
# Out:
# RandomForestClassifier(max_depth=3, random_state=0)

# %%
df_23 = pd.read_csv('/content/drive/MyDrive/AIFD_project/Work_2/notebooks/df_23_multiclass.csv')

# %%
df_23
# Out:
#          time       phi       psi     theta  mode  ...   m1   m2  add1  add2  fault
# 0        44.0 -0.019257  3.113642 -0.075649   0.0  ...  1.0  1.0   0.0   0.0      0
# 1        44.1 -0.019314  3.113563 -0.075712   0.0  ...  1.0  1.0   0.0   0.0      0
# 2        44.2 -0.019308  3.113501 -0.075723   0.0  ...  1.0  1.0   0.0   0.0      0
# 3        44.3 -0.019300  3.113426 -0.075736   0.0  ...  1.0  1.0   0.0   0.0      0
# 4        44.4 -0.019351  3.113332 -0.075727   0.0  ...  1.0  1.0   0.0   0.0      0
# ...       ...       ...       ...       ...   ...  ...  ...  ...   ...   ...    ...
# 32282  3269.5 -0.017212 -3.020877 -0.070188   0.0  ...  1.0  1.0   0.0   0.0      0
# 32283  3269.6 -0.015179 -3.021151 -0.069231   0.0  ...  1.0  1.0   0.0   0.0      0
# 32284  3269.7 -0.014398 -3.020987 -0.068787   0.0  ...  1.0  1.0   0.0   0.0      0
# 32285  3269.8 -0.013408 -3.020862 -0.068531   0.0  ...  1.0  1.0   0.0   0.0      0
# 32286  3269.9 -0.013137 -3.020602 -0.068579   0.0  ...  1.0  1.0   0.0   0.0      0
#
# [32287 rows x 50 columns]

# %%
X_23 = df_23.iloc[:,:-1]
y_23 = df_23.iloc[:,-1]

# %%
pred_23 = clf.predict(X_23)

# %%
print(classification_report(y_23, pred_23))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      1.00      0.84     16955
#            1       1.00      0.36      0.53      2527
#            2       0.00      0.00      0.00      1431
#            3       0.00      0.00      0.00      1458
#            4       0.00      0.00      0.00      1481
#            5       0.00      0.00      0.00      1505
#            6       0.34      0.62      0.44      1549
#            7       0.83      0.02      0.04      1620
#            8       0.72      0.97      0.83      3761
#
#     accuracy                           0.70     32287
#    macro avg       0.40      0.33      0.30     32287
# weighted avg       0.60      0.70      0.60     32287
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_23, pred_23)
cm
# Out:
# array([[16955,     0,     0,     0,     0,     0,     0,     0,     0],
#        [ 1622,   905,     0,     0,     0,     0,     0,     0,     0],
#        [ 1431,     0,     0,     0,     0,     0,     0,     0,     0],
#        [ 1456,     0,     0,     0,     0,     0,     0,     0,     2],
#        [ 1269,     0,     0,     0,     0,     0,    90,     0,   122],
#        [  567,     0,     0,     0,     0,     0,   587,     0,   351],
#        [  112,     0,     0,     0,     0,     0,   959,     6,   472],
#        [   54,     0,     0,     0,     0,     0,  1093,    30,   443],
#        [   58,     0,     0,     0,     0,     0,    67,     0,  3636]])

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

plt.show()

# %%
pred = clf.predict(X_train)

# %%
print(classification_report(y_train, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     11771
#            1       1.00      0.90      0.95      1923
#            2       0.98      0.64      0.77      1188
#            3       0.92      0.13      0.22      1194
#            4       0.45      0.03      0.05      1198
#            5       0.51      0.80      0.62      1222
#            6       0.86      0.81      0.84      1245
#            7       0.82      0.68      0.74      1283
#            8       0.89      0.97      0.93      2848
#
#     accuracy                           0.84     23872
#    macro avg       0.81      0.66      0.67     23872
# weighted avg       0.84      0.84      0.81     23872
